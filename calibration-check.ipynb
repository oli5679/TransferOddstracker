# %%
import pandas as pd

# %%
import os, sys

path = "output/data"
files = os.listdir(path)
combined_df = pd.DataFrame()
for file in files:
    if '.csv' in file and '2019' in file:
        file_df = pd.read_csv(f'output/data/{file}')
        file_df['file'] = file
        combined_df = combined_df.append(file_df)

# %%
len(combined_df['player'].unique())
# Out:
# 170

# %%
combined_df['player']
# Out:
# 0       David De Gea
# 1       David De Gea
# 2       David De Gea
# 3       David De Gea
# 4       David De Gea
#            ...
# 909    Kylian Mbappe
# 910    Kylian Mbappe
# 911    Kylian Mbappe
# 912    Kylian Mbappe
# 913    Kylian Mbappe
# Name: player, Length: 27880, dtype: object

# %%
import requests

# %%
url = 'https://fbref.com/search/search.fcgi?search={}'

# %%
name_a = 'David De Gea'.lower().replace(' ','+')

# %%
url.format(name_a)
# Out:
# 'https://fbref.com/search/search.fcgi?search=david+de+gea'

# %%
response = requests.get(url.format(name_a))

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# %%
r =soup.find("a", class_="div:nth-child(2) > p:nth-child(7) > a")

# %%
soup.find('a')
# Out:
# <a class="pt" href="https://fbref.com/pt/players/7ba6d84e/David-de-Gea" onclick="sr_set_trans_choice('pt');">Português</a>

# %%
from lxml import etree

# %%
htmlparser = etree.HTMLParser()
tree = etree.parse(response.text, htmlparser)
tree.xpath(xpathselector)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-b34db5cc0ae4> in <module>
#       1 htmlparser = etree.HTMLParser()
# ----> 2 tree = etree.parse(response.text, htmlparser)
#       3 tree.xpath(xpathselector)
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# OSError: Error reading file '
#
# <!DOCTYPE html>
# ...
